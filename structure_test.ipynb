# %%
from structure.guest import *
# Out:
# 1123123

# %%
GuestLoader('NH3')
# Out:
# [INFO] Downloaded: NH3.sdf
# [INFO] Saved optimized structure to NH3.xyz

# %%
import ase.io

# %%
from ase.visualize import view

# %%
view(ase.io.read('NH3.xyz'))
# Out:
# <Popen: returncode: None args: ['/home/users/skyljw0714/anaconda3/envs/auto-...>

# %%
GuestLoader('CO2')
# Out:
# [INFO] Downloaded: CO2.sdf
# [INFO] Saved optimized structure to CO2.xyz

# %%
GuestLoader('Carbon dioxide')
# Out:
# [INFO] Downloaded: Carbon dioxide.sdf
# [INFO] Saved optimized structure to Carbon dioxide.xyz
