# %%
# %load_ext autoreload
# %autoreload 2
import main
from ZeoPP.zeopp import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
query = main.interactive_mode()
# Out:
# MOF Simulation Analyzer. Type 'quit' to exit.
# ...
# User input:  How large is the largest diameter in UiO-66?
# Analyzing...
# === MOF Simulation Analysis Results ===
# 1) simulation tool: zeopp
# 2) simulation property: largest diameter
# 3) MOF: UiO-66
# 4) guest: None
#
# === JSON Format ===
# {
#   "simulation_tool": "zeopp",
#   "simulation_property": "largest diameter",
#   "MOF": "UiO-66",
#   "guest": null
# }
#
# ...
# Parsed query: {'simulation_tool': 'zeopp', 'simulation_property': 'largest diameter', 'MOF': 'UiO-66', 'guest': None, 'raw_query': 'How large is the largest diameter in UiO-66?'}
# [INFO] Zeo++ 명령어: /home/users/skyljw0714/AutoResearch/ZeoPP/network -ha -res /home/users/skyljw0714/AutoResearch/working_dir/uio-66.cif
#
# [Answer]
# ...

# %%
raspa_query = {
  "simulation_tool": "RASPA",
  "simulation_property": "adsorption isotherm",
  "MOF": "UiO-66",
  "guest": "CO2"
}
